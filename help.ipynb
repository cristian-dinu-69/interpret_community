# %% [markdown]
# # API Reference

# %% [markdown]
# https://interpret.ml/docs/interpret.html
#
# https://www.youtube.com/watch?v=WwBeKMQ0-I8

# %% [markdown]
# ## interpret.glassbox
#
# + designed to be interpretable (linear models and Decision trees)
#
#
#
# + ExplainableBoostingClassifier,
#
# + ExplainableBoostingRegressor
# + LogisticRegression
#
# + LinearRegression
#
# + ClassificationTree
#
# + RegressionTree
#
# + DecisionListClassifier
#
# + erge_ebms
#
# ## interpret.blackbox
#
# + ShapKernel
#
# + LimeTabular
#
# + PartialDependence
#
# + MorrisSensitivity
#
# ## interpret.greybox
#
# + ShapTree
#
#
#
# ## interpret.perf
#
# + RegressionPerf
#
# + ROC
#
# + PR
#
# ## interpret.data
#
# + ClassHistogram
#
# + Marginal
#
# ## interpret.privacy
#
# + DPExplainableBoostingClassifier
#
# + DPExplainableBoostingRegressor
#
# ## interpret.utils
#
# + measure_interactions
#
#
#
# ## interpret.develop
#
# ## debug_mode
#
# ## show
#
# ## show_link
#
# ## set_show_addr
#
# ## get_show_addr
#
# ## preserve
#
# ## shutdown_show_server
#
# ## init_show_server
#
# ## status_show_server
#
# ## set_visualize_provider
#
# ## get_visualize_provider
